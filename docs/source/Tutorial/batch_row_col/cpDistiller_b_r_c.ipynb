# %% [markdown]
# # The removal of triple effects using cpDistiller

# %%
import scanpy as sc
import anndata as ad
from cpDistiller import DataSet,labeled,cpDistiller_Model,merge_csv2h5ad,merge_csv,MAD
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <div class="alert note">
# <p>
# UMAP visualization of 12 batches demonstrated triple effects, including batch, row, and column effects.
# </p>
# </div>

# %%
data = ad.read_h5ad('/data/pub/cell/cpg0016_source4/cpg0016orf.h5ad')
sc.pp.scale(data)    
sc.pp.neighbors(data, n_neighbors=15)
sc.tl.umap(data, random_state=9000, min_dist=0.1)
plt.figure(figsize=(15, 5))
sc.pl.umap(data, color="batch", ax=plt.subplot(1, 3, 1), show=False)
plt.title('UMAP: Batch')
sc.pl.umap(data, color="row", palette='plasma', ax=plt.subplot(1, 3, 2), show=False)
plt.title('UMAP: Row (Plasma)')
sc.pl.umap(data, color="col", palette='viridis', ax=plt.subplot(1, 3, 3), show=False)
plt.title('UMAP: Col (Viridis)')
plt.tight_layout()
plt.show()
# Out:
# WARNING: You’re trying to run this on 1446 dimensions of `.X`, if you really want this, set `use_rep='X'`.
#          Falling back to preprocessing with `sc.pp.pca` and default params.

# %% [markdown]
# <div class="alert note">
# <p>
# We used cpDistiller to correct triple effects, using both cpDistiller-extractor-based features and CellProfiler-based features.
# </p>
# </div>

# %%
data_all = ad.read_h5ad('/data/pub/cell/cpg0016_source4/cpg0016orf.h5ad')
data_csv = merge_csv('/data/pub/cell/cpg0016_source4/merged_embeddings_all/')
data_concat = merge_csv2h5ad(data_csv,data_all)
data_concat = MAD(data_concat)
sc.pp.scale(data_concat)   
dat = DataSet(data_concat,batch_size=256,mod=1)
labeled(data_concat,Mnn=5,Knn=10,Mnn_list=['batch','row','col'],Knn_list=['batch','row','col'])   
cpDistiller =  cpDistiller_Model(dat,epochs=50,model_path='./ckpts/',reduction='mean',mo='cpDistiller-B',name='1000')
cpDistiller.load_model('/data/ckpts/1000/final_model_ema.ckpt')
cpDistiller.train()
result,category = cpDistiller.eval(dat.data)
name = 'cpDistiller_embeddings'
data.obsm[name]=result
sc.pp.neighbors(data, n_neighbors=15, use_rep=name)
sc.tl.umap(data, random_state=9000, min_dist=0.1)
plt.figure(figsize=(15, 5))
sc.pl.umap(data, color="batch", ax=plt.subplot(1, 3, 1), show=False)
plt.title('UMAP: Batch')
sc.pl.umap(data, color="row", palette='plasma', ax=plt.subplot(1, 3, 2), show=False)
plt.title('UMAP: Row (Plasma)')
sc.pl.umap(data, color="col", palette='viridis', ax=plt.subplot(1, 3, 3), show=False)
plt.title('UMAP: Col (Viridis)')
plt.tight_layout()
plt.show()
# Out:
# 2025-05-23 04:11:52,908 - INFO - MNN pairs num: 122312
# 2025-05-23 04:12:10,532 - INFO - KNN pairs num: 23401
# 2025-05-23 04:13:07,025 - INFO - GMVAE_DL(
#   (pca_attention): PCAAttentionBlock(
#     (attention): EfficientAttention(
#       (avg_pool): AdaptiveAvgPool2d(output_size=1)
#       (conv1): Conv1d(1, 1, kernel_size=(1,), stride=(1,), bias=False)
#       (sigmoid): Sigmoid()
#     )
#     (pca_linear): Linear(in_features=144, out_features=32, bias=True)
#     (attetion_linear): Linear(in_features=144, out_features=32, bias=True)
#     (attention_activation): LeakyReLU(negative_slope=0.01)
#     (output_linear): Linear(in_features=32, out_features=144, bias=True)
#     (output_activation): LeakyReLU(negative_slope=0.01)
#   )
#   (encode): GM_Encoder(
#     (qy_x): Sequential(
#       (0): Linear(in_features=1590, out_features=512, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): Linear(in_features=512, out_features=512, bias=True)
#       (3): LeakyReLU(negative_slope=0.01)
#     )
#     (GumbelSoftmax): GumbelSoftmax(
#       (logits): Linear(in_features=512, out_features=10, bias=True)
#     )
#     (qz_yx): Sequential(
#       (0): Linear(in_features=1600, out_features=512, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): Linear(in_features=512, out_features=512, bias=True)
#       (3): LeakyReLU(negative_slope=0.01)
#     )
#     (Gaussian): Gaussian(
#       (mu): Sequential(
#         (0): Linear(in_features=512, out_features=50, bias=True)
#       )
#       (var): Sequential(
#         (0): Linear(in_features=512, out_features=50, bias=True)
#         (1): Softplus(beta=1, threshold=20)
#       )
#     )
#     (projection_head): Sequential(
#       (0): Linear(in_features=50, out_features=50, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#     )
#   )
#   (decode): GM_Decoder(
#     (y_mu): Sequential(
#       (0): Linear(in_features=10, out_features=50, bias=True)
#     )
#     (y_var): Sequential(
#       (0): Linear(in_features=10, out_features=50, bias=True)
#       (1): Softplus(beta=1, threshold=20)
#     )
#     (px_z): Sequential(
#       (0): Linear(in_features=50, out_features=512, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): Linear(in_features=512, out_features=512, bias=True)
#       (3): LeakyReLU(negative_slope=0.01)
#       (4): Linear(in_features=512, out_features=1590, bias=True)
#     )
#   )
#   (max_pooling): MaxPool2d(kernel_size=9, stride=9, padding=0, dilation=1, ceil_mode=False)
# )
# 2025-05-23 04:13:07,028 - INFO - Discriminator(
#   (main): Sequential(
#     (0): Linear(in_features=50, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=128, out_features=16, bias=True)
#   )
# )
# 2025-05-23 04:13:07,029 - INFO - Discriminator(
#   (main): Sequential(
#     (0): Linear(in_features=50, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=128, out_features=24, bias=True)
#   )
# )
# 2025-05-23 04:13:07,031 - INFO - Discriminator(
#   (main): Sequential(
#     (0): Linear(in_features=50, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=128, out_features=12, bias=True)
#   )
# )
# 2025-05-23 04:21:48,355 - INFO - epoch:0 average loss:793.54 ELBO:446.52 D loss:323.50 triplet loss:23.53
# 2025-05-23 04:21:48,356 - INFO - acc batch:17.14% ,acc row:22.52% ,acc col:22.00%
# 2025-05-23 04:28:18,152 - INFO - epoch:5 average loss:755.93 ELBO:438.38 D loss:297.61 triplet loss:19.94
# 2025-05-23 04:28:18,153 - INFO - acc batch:30.39% ,acc row:27.72% ,acc col:26.30%
# 2025-05-23 04:34:31,234 - INFO - epoch:10 average loss:776.55 ELBO:444.55 D loss:315.02 triplet loss:16.98
# 2025-05-23 04:34:31,236 - INFO - acc batch:25.61% ,acc row:25.51% ,acc col:22.28%
# 2025-05-23 04:40:54,530 - INFO - epoch:15 average loss:774.67 ELBO:443.63 D loss:317.02 triplet loss:14.02
# 2025-05-23 04:40:54,531 - INFO - acc batch:25.81% ,acc row:25.08% ,acc col:21.37%
# 2025-05-23 04:46:09,303 - INFO - epoch:20 average loss:772.68 ELBO:442.32 D loss:318.64 triplet loss:11.71
# 2025-05-23 04:46:09,304 - INFO - acc batch:25.49% ,acc row:25.08% ,acc col:21.16%
# 2025-05-23 04:48:18,581 - INFO - epoch:25 average loss:763.42 ELBO:435.74 D loss:318.31 triplet loss:9.37
# 2025-05-23 04:48:18,582 - INFO - acc batch:24.94% ,acc row:25.05% ,acc col:21.31%
# 2025-05-23 04:50:30,248 - INFO - epoch:30 average loss:757.31 ELBO:431.56 D loss:318.09 triplet loss:7.66
# 2025-05-23 04:50:30,250 - INFO - acc batch:25.45% ,acc row:25.45% ,acc col:21.36%
# 2025-05-23 04:52:42,084 - INFO - epoch:35 average loss:751.97 ELBO:427.85 D loss:317.22 triplet loss:6.91
# 2025-05-23 04:52:42,085 - INFO - acc batch:25.72% ,acc row:25.61% ,acc col:21.73%
# 2025-05-23 04:54:48,395 - INFO - epoch:40 average loss:749.53 ELBO:425.51 D loss:318.25 triplet loss:5.77
# 2025-05-23 04:54:48,397 - INFO - acc batch:25.35% ,acc row:25.58% ,acc col:21.65%
# 2025-05-23 04:56:54,160 - INFO - epoch:45 average loss:747.49 ELBO:423.80 D loss:318.29 triplet loss:5.40
# 2025-05-23 04:56:54,162 - INFO - acc batch:25.44% ,acc row:25.50% ,acc col:21.66%

# %% [markdown]
# <div class="alert note">
# <p>
# We observed perturbations on target plates, using the UMAP to illustrate the degree of differentiation among different ORF perturbations. The perturbations on target plates are typically used for data alignment (see <a href="https://www.nature.com/articles/s41467-024-50613-5" target="_blank">here</a>).
# </p>
# </div>

# %%
perturbation=['JCP2022_062592', 'JCP2022_009867', 'JCP2022_047545', 'JCP2022_017377', 'JCP2022_032680', 
               'JCP2022_064022', 'JCP2022_069131', 'JCP2022_084606', 'JCP2022_000794', 'JCP2022_116749', 
               'JCP2022_077089', 'JCP2022_027206', 'JCP2022_064903', 'JCP2022_068713', 'JCP2022_106219',
               'JCP2022_033400', 'JCP2022_055397', 'JCP2022_011759', 'JCP2022_054601', 'JCP2022_067432', 
               'JCP2022_067441', 'JCP2022_055904', 'JCP2022_060734', 'JCP2022_033914','JCP2022_046462',
               'JCP2022_116560', 'JCP2022_010404', 'JCP2022_014367', 'JCP2022_039863','JCP2022_115963',
               'JCP2022_007613','JCP2022_100876','JCP2022_050162','JCP2022_061654']

# %%
data_choosen = data[data.obs['Metadata_JCP2022'].isin(perturbation)]
sc.pp.neighbors(data_choosen, n_neighbors=15, use_rep=name, metric="cosine")
sc.tl.umap(data_choosen)
sc.pl.umap(data_choosen, color="Metadata_JCP2022")

# %% [markdown]
# <div class="alert note">
# <p>
# We used cpDistiller-C to correct triple effects, using only CellProfiler-based features.
# </p>
# </div>

# %%
data_all = ad.read_h5ad('/data/pub/cell/cpg0016_source4/cpg0016orf.h5ad')
data_concat = MAD(data_all)
sc.pp.scale(data_concat)   
dat = DataSet(data_concat,batch_size=256,mod=1)
labeled(data_concat,Mnn=5,Knn=10,Mnn_list=['batch','row','col'],Knn_list=['batch','row','col'],deep_dim=0) 
cpDistiller =  cpDistiller_Model(dat,epochs=50,model_path='./ckpts/',name='1000_cell',reduction='mean',mo='cpDistiller-C') #  Alternatively, you can set the 'mo' to 'cpDistiller-C' but provide only cpDistiller-extractor-based features as input, using a variant that does not rely on CellProfiler-based features (cpDistiller-D).
cpDistiller.load_model('/data/ckpts/1000_cell/final_model_ema.ckpt')
cpDistiller.train()
result,category = cpDistiller.eval(dat.data)
name = 'cpDistiller_embeddings_cell'
data.obsm[name]=result
sc.pp.neighbors(data, n_neighbors=15, use_rep=name)
sc.tl.umap(data, random_state=9000, min_dist=0.1)
plt.figure(figsize=(15, 5))
sc.pl.umap(data, color="batch", ax=plt.subplot(1, 3, 1), show=False)
plt.title('UMAP: Batch')
sc.pl.umap(data, color="row", palette='plasma', ax=plt.subplot(1, 3, 2), show=False)
plt.title('UMAP: Row (Plasma)')
sc.pl.umap(data, color="col", palette='viridis', ax=plt.subplot(1, 3, 3), show=False)
plt.title('UMAP: Col (Viridis)')
plt.tight_layout()
plt.show()
# Out:
# 2025-05-23 17:22:50,915 - INFO - MNN pairs num: 182682
# 2025-05-23 17:23:06,498 - INFO - KNN pairs num: 27622
# 2025-05-23 17:23:48,568 - INFO - GMVAE(
#   (encode): GM_Encoder(
#     (qy_x): Sequential(
#       (0): Linear(in_features=1446, out_features=512, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): Linear(in_features=512, out_features=512, bias=True)
#       (3): LeakyReLU(negative_slope=0.01)
#     )
#     (GumbelSoftmax): GumbelSoftmax(
#       (logits): Linear(in_features=512, out_features=10, bias=True)
#     )
#     (qz_yx): Sequential(
#       (0): Linear(in_features=1456, out_features=512, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): Linear(in_features=512, out_features=512, bias=True)
#       (3): LeakyReLU(negative_slope=0.01)
#     )
#     (Gaussian): Gaussian(
#       (mu): Sequential(
#         (0): Linear(in_features=512, out_features=50, bias=True)
#       )
#       (var): Sequential(
#         (0): Linear(in_features=512, out_features=50, bias=True)
#         (1): Softplus(beta=1, threshold=20)
#       )
#     )
#     (projection_head): Sequential(
#       (0): Linear(in_features=50, out_features=50, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#     )
#   )
#   (decode): GM_Decoder(
#     (y_mu): Sequential(
#       (0): Linear(in_features=10, out_features=50, bias=True)
#     )
#     (y_var): Sequential(
#       (0): Linear(in_features=10, out_features=50, bias=True)
#       (1): Softplus(beta=1, threshold=20)
#     )
#     (px_z): Sequential(
#       (0): Linear(in_features=50, out_features=512, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): Linear(in_features=512, out_features=512, bias=True)
#       (3): LeakyReLU(negative_slope=0.01)
#       (4): Linear(in_features=512, out_features=1446, bias=True)
#     )
#   )
# )
# 2025-05-23 17:23:48,570 - INFO - Discriminator(
#   (main): Sequential(
#     (0): Linear(in_features=50, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=128, out_features=16, bias=True)
#   )
# )
# 2025-05-23 17:23:48,571 - INFO - Discriminator(
#   (main): Sequential(
#     (0): Linear(in_features=50, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=128, out_features=24, bias=True)
#   )
# )
# 2025-05-23 17:23:48,572 - INFO - Discriminator(
#   (main): Sequential(
#     (0): Linear(in_features=50, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.01)
#     (2): Linear(in_features=128, out_features=128, bias=True)
#     (3): LeakyReLU(negative_slope=0.01)
#     (4): Linear(in_features=128, out_features=12, bias=True)
#   )
# )
# 2025-05-23 17:31:50,722 - INFO - epoch:0 average loss:743.79 ELBO:438.96 D loss:286.15 triplet loss:18.68
# 2025-05-23 17:31:50,724 - INFO - acc batch:19.19% ,acc row:23.91% ,acc col:24.37%
# 2025-05-23 17:37:27,869 - INFO - epoch:5 average loss:718.45 ELBO:432.46 D loss:267.95 triplet loss:18.04
# 2025-05-23 17:37:27,871 - INFO - acc batch:30.52% ,acc row:28.10% ,acc col:26.64%
# 2025-05-23 17:42:41,541 - INFO - epoch:10 average loss:741.31 ELBO:441.90 D loss:282.17 triplet loss:17.24
# 2025-05-23 17:42:41,543 - INFO - acc batch:26.87% ,acc row:25.97% ,acc col:23.00%
# 2025-05-23 17:48:08,063 - INFO - epoch:15 average loss:743.81 ELBO:441.49 D loss:286.73 triplet loss:15.58
# 2025-05-23 17:48:08,065 - INFO - acc batch:25.78% ,acc row:25.13% ,acc col:22.20%
# 2025-05-23 17:52:28,636 - INFO - epoch:20 average loss:740.95 ELBO:439.44 D loss:288.61 triplet loss:12.90
# 2025-05-23 17:52:28,638 - INFO - acc batch:25.27% ,acc row:25.02% ,acc col:21.47%
# 2025-05-23 17:53:23,009 - INFO - epoch:25 average loss:730.98 ELBO:433.87 D loss:286.59 triplet loss:10.51
# 2025-05-23 17:53:23,011 - INFO - acc batch:25.96% ,acc row:25.38% ,acc col:21.95%
# 2025-05-23 17:54:16,385 - INFO - epoch:30 average loss:726.16 ELBO:430.57 D loss:287.34 triplet loss:8.25
# 2025-05-23 17:54:16,387 - INFO - acc batch:25.54% ,acc row:25.23% ,acc col:22.05%
# 2025-05-23 17:55:18,866 - INFO - epoch:35 average loss:718.75 ELBO:426.31 D loss:286.24 triplet loss:6.19
# 2025-05-23 17:55:18,869 - INFO - acc batch:26.13% ,acc row:25.71% ,acc col:22.29%
# 2025-05-23 17:56:14,968 - INFO - epoch:40 average loss:714.64 ELBO:423.62 D loss:286.31 triplet loss:4.71
# 2025-05-23 17:56:14,970 - INFO - acc batch:26.28% ,acc row:25.65% ,acc col:22.14%
# 2025-05-23 17:57:13,160 - INFO - epoch:45 average loss:716.02 ELBO:423.35 D loss:288.31 triplet loss:4.37
# 2025-05-23 17:57:13,162 - INFO - acc batch:25.52% ,acc row:25.27% ,acc col:22.01%

# %%
data_choosen = data[data.obs['Metadata_JCP2022'].isin(perturbation)]
sc.pp.neighbors(data_choosen, n_neighbors=15, use_rep=name, metric="cosine")
sc.tl.umap(data_choosen)
sc.pl.umap(data_choosen, color="Metadata_JCP2022")
